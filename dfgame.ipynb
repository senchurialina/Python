# %%
import pygame
import cv2
from deepface import DeepFace

pygame.init()
screen = pygame.display.set_mode((800, 400))
pygame.display.set_caption("Alina's Game")

player = pygame.Rect(50, 100, 50, 50)
player_color = (0,0,255)
screen_color = (255,255,255)

cam = cv2.VideoCapture(0)

TAKE_PICTURE = pygame.USEREVENT + 1
pygame.time.set_timer(TAKE_PICTURE, 2000)

running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        if event.type == TAKE_PICTURE:
            print("Taking picture")
            success, image_matlike = cam.read()
            if success:
                try:
                  result = DeepFace.analyze(image_matlike, actions = ['emotion'])
                  print(result)
                  emotion = result[0]["dominant_emotion"]
                  if emotion == "happy":
                     player.x +=10
                except:
                  print("SHOW YOUR FACE TO THE CAMERA")
    screen.fill(screen_color)
    pygame.draw.rect(screen, player_color, player)

    pygame.display.update()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:tensorflow:From c:\Users\Alina\OneDrive\Desktop\Python\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Taking picture
# [{'emotion': {'angry': np.float32(0.0012109809), 'disgust': np.float32(8.4949716e-07), 'fear': np.float32(1.4930434e-05), 'happy': np.float32(99.40689), 'sad': np.float32(0.019410819), 'surprise': np.float32(0.00024441024), 'neutral': np.float32(0.572212)}, 'dominant_emotion': 'happy', 'region': {'x': 233, 'y': 150, 'w': 233, 'h': 233, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.89}]
# Taking picture
# ...
