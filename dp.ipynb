# %%
from deepface import DeepFace

res = DeepFace.verify("cel1.jpg", "cel2.jpg")
print(res)
# Out:
# WARNING:tensorflow:From c:\Users\Alina\OneDrive\Desktop\Python\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# {'verified': True, 'distance': 0.354806, 'threshold': 0.68, 'confidence': 85.99, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 136, 'y': 124, 'w': 248, 'h': 248, 'left_eye': (306, 229), 'right_eye': (220, 210)}, 'img2': {'x': 61, 'y': 139, 'w': 240, 'h': 240, 'left_eye': (221, 220), 'right_eye': (131, 238)}}, 'time': 33.81}

# %%
# %pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (82.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.4.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.46.3)
# Requirement already satisfied: rich in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.3.2)
# Requirement already satisfied: namex in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10.2)
# Requirement already satisfied: pillow in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alina\onedrive\desktop\python\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from deepface import DeepFace

DeepFace.find("cel1.jpg", "imagescoding")
# Out:
# 26-02-24 19:13:40 - Searching cel1.jpg in 8 length datastore
# 26-02-24 19:13:42 - find function duration 2.7569644451141357 seconds
# [                identity                                      hash  target_x  \
#  0  imagescoding\cel1.jpg  e7431b86e8f3d9750d3cb161f1b8a990afb78261       136
#  1     imagescoding\3.jpg  fd39777ab61c83b63e6069c28b552edda8bad912        82
#
#     target_y  target_w  target_h  threshold  source_x  source_y  source_w  \
#  0       124       248       248       0.68       136       124       248
#  1       138       518       518       0.68       136       124       248
#
#     source_h  distance  confidence
#  0       248  0.085518      100.00
#  1       248  0.669515       51.68  ]

# %%
from deepface import DeepFace

res = DeepFace.analyze("cel1.jpg")
print(res)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 26-02-24 19:17:57 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to C:\Users\Alina\.deepface\weights\facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Alina\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 38.0MB/s]
# Action: age:  25%|██▌       | 1/4 [00:05<00:16,  5.58s/it]
# 26-02-24 19:18:07 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to C:\Users\Alina\.deepface\weights\age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Alina\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [00:06<00:00, 80.3MB/s]
# Action: gender:  50%|█████     | 2/4 [00:31<00:34, 17.41s/it]
# 26-02-24 19:18:31 - 🔗 gender_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5 to C:\Users\Alina\.deepface\weights\gender_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Alina\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [00:08<00:00, 60.9MB/s]
# Action: race:  75%|███████▌  | 3/4 [00:54<00:20, 20.04s/it]
# 26-02-24 19:18:53 - 🔗 race_model_single_batch.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5 to C:\Users\Alina\.deepface\weights\race_model_single_batch.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\Alina\.deepface\weights\race_model_single_batch.h5
# 100%|██████████| 537M/537M [00:07<00:00, 75.3MB/s]
# Action: race: 100%|██████████| 4/4 [01:14<00:00, 18.61s/it]
# [{'emotion': {'angry': np.float32(0.0053553907), 'disgust': np.float32(4.3743352e-08), 'fear': np.float32(0.2529388), 'happy': np.float32(27.579914), 'sad': np.float32(0.023529164), 'surprise': np.float32(0.00029627094), 'neutral': np.float32(72.13797)}, 'dominant_emotion': 'neutral', 'region': {'x': 136, 'y': 124, 'w': 248, 'h': 248, 'left_eye': (306, 229), 'right_eye': (220, 210)}, 'face_confidence': 0.9, 'age': 23, 'gender': {'Woman': np.float32(0.17307015), 'Man': np.float32(99.826935)}, 'dominant_gender': 'Man', 'race': {'asian': np.float32(0.00070004474), 'indian': np.float32(0.0014594973), 'black': np.float32(1.5860425e-05), 'white': np.float32(96.49362), 'middle eastern': np.float32(1.4472786), 'latino hispanic': np.float32(2.0569303)}, 'dominant_race': 'white'}]

# %%
from deepface import DeepFace

res = DeepFace.analyze("mepicture.jpg")
print(res)
# Out:
# Action: race: 100%|██████████| 4/4 [00:26<00:00,  6.70s/it]
# [{'emotion': {'angry': np.float32(5.8479905e-05), 'disgust': np.float32(4.749541e-10), 'fear': np.float32(2.7798401e-07), 'happy': np.float32(99.99865), 'sad': np.float32(0.0006737036), 'surprise': np.float32(4.1804643e-08), 'neutral': np.float32(0.0006110209)}, 'dominant_emotion': 'happy', 'region': {'x': 535, 'y': 253, 'w': 267, 'h': 267, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.89, 'age': 29, 'gender': {'Woman': np.float32(11.227679), 'Man': np.float32(88.77232)}, 'dominant_gender': 'Man', 'race': {'asian': np.float32(19.858202), 'indian': np.float32(21.20836), 'black': np.float32(7.302515), 'white': np.float32(9.38107), 'middle eastern': np.float32(8.4544115), 'latino hispanic': np.float32(33.79544)}, 'dominant_race': 'latino hispanic'}]
